# %%
import openai
import weaviate
import os
from dotenv import load_dotenv
import pandas as pd

# Carregar variáveis de ambiente
load_dotenv()

# Configuração da API OpenAI
openai.api_key = os.environ.get("OPENAI_API_KEY")
api_key=os.environ.get("WEAVIATE_API_KEY")
url=os.environ.get("WEAVIATE_URL")


# Conexão com o Weaviate
client_wv8 = weaviate.Client(
    url=os.environ.get("WEAVIATE_URL"),
    auth_client_secret=weaviate.AuthApiKey(api_key=os.environ.get("WEAVIATE_API_KEY")),
    additional_headers={
        "X-OpenAI-Api-Key": openai.api_key,
    }
)
# Criar o schema dinamicamente
schema = {
    "classes": [
        {
            "class": "DocsOportunidades",
            "description": "Detalhes de melhorias em processos empresariais",
            "properties": [
                {"name": "EMPRESA", "dataType": ["text"], "description": "Nome da empresa"},
                {"name": "SEGMENTO_MERCADO", "dataType": ["text"], "description": "Segmento de mercado"},
                {"name": "PROCESSO", "dataType": ["text"], "description": "Descrição do processo"},
                {"name": "ATIVIDADE_RELACIONADA", "dataType": ["text"], "description": "Atividade relacionada ao processo"},
                {"name": "MELHORIA_SUGERIDA", "dataType": ["text"], "description": "Categoria da melhoria sugerida"},
                {"name": "GAPS", "dataType": ["text"], "description": "Problemas ou lacunas identificadas"},
                {"name": "CAUSA", "dataType": ["text"], "description": "Causa raiz do problema"},
                {"name": "SOLUCAO", "dataType": ["text"], "description": "Proposta de melhoria ou solução"},
                {"name": "GANHOS", "dataType": ["text"], "description": "Ganhos ou objetivos esperados com a solução"}
            ],
            "vectorizer": "text2vec-openai"
        }
    ]
}

# Verificar se o schema existe, se não, criá-lo
class_name = "DocsOportunidades"
existing_classes = [cls["class"] for cls in client_wv8.schema.get().get("classes", [])]

if class_name not in existing_classes:
    client_wv8.schema.create(schema)
    print(f"Schema '{class_name}' criado com sucesso.")
else:
    print(f"Schema '{class_name}' já existe.")

# Carregar os dados
df_base = pd.read_excel('Base.xlsx', skiprows=2, header=1)
df_base = df_base.iloc[:, :9]
df_base = df_base.fillna("Não informado")

renomear = {
    "EMPRESA": "EMPRESA",
    "SEGMENTO DE MERCADO": "SEGMENTO_MERCADO",
    "PROCESSO": "PROCESSO",
    "ATIVIDADE RELACIONADA": "ATIVIDADE_RELACIONADA",
    "TIPO DE MELHORIA": "MELHORIA_SUGERIDA",
    "DESCONEXÕES (GAP)": "GAPS",
    "CAUSA": "CAUSA",
    "MELHORIA/SOLUÇÃO": "SOLUCAO",
    "GANHOS/OBJETIVO": "GANHOS"
}

df_base = df_base.rename(columns=renomear)

# Preparar os dados para inserção
lista = df_base.to_dict(orient='records')

# Inserir os dados no Weaviate
try:
    client_wv8.batch.configure(batch_size=100)
    with client_wv8.batch as batch:
        for i, d in enumerate(lista):
            properties = {
                "EMPRESA": d['EMPRESA'],
                "SEGMENTO_MERCADO": d['SEGMENTO_MERCADO'],
                "PROCESSO": d['PROCESSO'],
                "ATIVIDADE_RELACIONADA": d['ATIVIDADE_RELACIONADA'],
                "MELHORIA_SUGERIDA": d['MELHORIA_SUGERIDA'],
                "GAPS": d['GAPS'],
                "CAUSA": d['CAUSA'],
                "SOLUCAO": d['SOLUCAO'],
                "GANHOS": d['GANHOS']
            }
            try:
                batch.add_data_object(
                    data_object=properties,
                    class_name="DocsOportunidades"
                )
                print(f"Registro {i + 1} importado com sucesso.")
            except Exception as e:
                print(f"Erro ao adicionar o registro {i + 1}: {e}")
except Exception as e:
    print(f"Erro ao iniciar o batch: {e}")
# Out:
# c:\Users\TiagoVettorazzi\AppData\Local\Programs\Python\Python313\Lib\site-packages\weaviate\__init__.py:144: DeprecationWarning: Dep010: Importing AuthApiKey from weaviate is deprecated. Import AuthApiKey from its module: weaviate.auth
#   _Warnings.root_module_import(name, map_[name])
# C:\Users\TiagoVettorazzi\AppData\Local\Temp\ipykernel_33732\32137680.py:17: DeprecationWarning:
# Python client v3 `weaviate.Client(...)` connections and methods are deprecated and will
#             be removed by 2024-11-30.
#
#             Upgrade your code to use Python client v4 `weaviate.WeaviateClient` connections and methods.
#                 - For Python Client v4 usage, see: https://weaviate.io/developers/weaviate/client-libraries/python
#                 - For code migration, see: https://weaviate.io/developers/weaviate/client-libraries/python/v3_v4_migration
#
#             If you have to use v3 code, install the v3 client and pin the v3 dependency in your requirements file: `weaviate-client>=3.26.7;<4.0.0`
#   client_wv8 = weaviate.Client(
# c:\Users\TiagoVettorazzi\AppData\Local\Programs\Python\Python313\Lib\site-packages\weaviate\warnings.py:186: DeprecationWarning: Dep016: Python client v3 `weaviate.Client(...)` connections and methods are deprecated and will
#             be removed by 2024-11-30.
#
#             Upgrade your code to use Python client v4 `weaviate.WeaviateClient` connections and methods.
#                 - For Python Client v4 usage, see: https://weaviate.io/developers/weaviate/client-libraries/python
#                 - For code migration, see: https://weaviate.io/developers/weaviate/client-libraries/python/v3_v4_migration
#
#             If you have to use v3 code, install the v3 client and pin the v3 dependency in your requirements file: `weaviate-client>=3.26.7;<4.0.0`
#   warnings.warn(
# c:\Users\TiagoVettorazzi\AppData\Local\Programs\Python\Python313\Lib\site-packages\weaviate\warnings.py:133: DeprecationWarning: Dep005: You are using weaviate-client version 4.9.6. The latest version is 4.13.2.
#             Consider upgrading to the latest version. See https://weaviate.io/developers/weaviate/client-libraries/python for details.
#   warnings.warn(
# Schema 'DocsOportunidades' criado com sucesso.
# Registro 1 importado com sucesso.
# Registro 2 importado com sucesso.
# Registro 3 importado com sucesso.
# Registro 4 importado com sucesso.
# Registro 5 importado com sucesso.
# Registro 6 importado com sucesso.
# Registro 7 importado com sucesso.
# Registro 8 importado com sucesso.
# Registro 9 importado com sucesso.
# Registro 10 importado com sucesso.
# Registro 11 importado com sucesso.
# Registro 12 importado com sucesso.
# Registro 13 importado com sucesso.
# Registro 14 importado com sucesso.
# Registro 15 importado com sucesso.
# Registro 16 importado com sucesso.
# Registro 17 importado com sucesso.
# Registro 18 importado com sucesso.
# Registro 19 importado com sucesso.
# Registro 20 importado com sucesso.
# Registro 21 importado com sucesso.
# Registro 22 importado com sucesso.
# Registro 23 importado com sucesso.
# Registro 24 importado com sucesso.
# Registro 25 importado com sucesso.
# Registro 26 importado com sucesso.
# Registro 27 importado com sucesso.
# Registro 28 importado com sucesso.
# Registro 29 importado com sucesso.
# Registro 30 importado com sucesso.
# Registro 31 importado com sucesso.
# Registro 32 importado com sucesso.
# Registro 33 importado com sucesso.
# Registro 34 importado com sucesso.
# Registro 35 importado com sucesso.
# Registro 36 importado com sucesso.
# Registro 37 importado com sucesso.
# Registro 38 importado com sucesso.
# Registro 39 importado com sucesso.
# Registro 40 importado com sucesso.
# Registro 41 importado com sucesso.
# Registro 42 importado com sucesso.
# Registro 43 importado com sucesso.
# Registro 44 importado com sucesso.
# Registro 45 importado com sucesso.
# Registro 46 importado com sucesso.
# Registro 47 importado com sucesso.
# Registro 48 importado com sucesso.
# Registro 49 importado com sucesso.
# Registro 50 importado com sucesso.
# Registro 51 importado com sucesso.
# Registro 52 importado com sucesso.
# Registro 53 importado com sucesso.
# Registro 54 importado com sucesso.
# Registro 55 importado com sucesso.
# Registro 56 importado com sucesso.
# Registro 57 importado com sucesso.
# Registro 58 importado com sucesso.
# Registro 59 importado com sucesso.
# Registro 60 importado com sucesso.
# Registro 61 importado com sucesso.
# Registro 62 importado com sucesso.
# Registro 63 importado com sucesso.
# Registro 64 importado com sucesso.
# Registro 65 importado com sucesso.
# Registro 66 importado com sucesso.
# Registro 67 importado com sucesso.
# Registro 68 importado com sucesso.
# Registro 69 importado com sucesso.
# Registro 70 importado com sucesso.
# Registro 71 importado com sucesso.
# Registro 72 importado com sucesso.
# Registro 73 importado com sucesso.
# Registro 74 importado com sucesso.
# Registro 75 importado com sucesso.
# Registro 76 importado com sucesso.
# Registro 77 importado com sucesso.
# Registro 78 importado com sucesso.
# Registro 79 importado com sucesso.
# Registro 80 importado com sucesso.
# Registro 81 importado com sucesso.
# Registro 82 importado com sucesso.
# Registro 83 importado com sucesso.
# Registro 84 importado com sucesso.
# Registro 85 importado com sucesso.
# Registro 86 importado com sucesso.
# Registro 87 importado com sucesso.
# Registro 88 importado com sucesso.
# Registro 89 importado com sucesso.
# Registro 90 importado com sucesso.
# Registro 91 importado com sucesso.
# Registro 92 importado com sucesso.
# Registro 93 importado com sucesso.
# Registro 94 importado com sucesso.
# Registro 95 importado com sucesso.
# Registro 96 importado com sucesso.
# Registro 97 importado com sucesso.
# Registro 98 importado com sucesso.
# Registro 99 importado com sucesso.
# Registro 100 importado com sucesso.
# Registro 101 importado com sucesso.
# Registro 102 importado com sucesso.
# Registro 103 importado com sucesso.
# Registro 104 importado com sucesso.
# Registro 105 importado com sucesso.
# Registro 106 importado com sucesso.
# Registro 107 importado com sucesso.
# Registro 108 importado com sucesso.
# Registro 109 importado com sucesso.
# Registro 110 importado com sucesso.
# Registro 111 importado com sucesso.
# Registro 112 importado com sucesso.
# Registro 113 importado com sucesso.
# Registro 114 importado com sucesso.
# Registro 115 importado com sucesso.
# Registro 116 importado com sucesso.
# Registro 117 importado com sucesso.
# Registro 118 importado com sucesso.
# Registro 119 importado com sucesso.
# Registro 120 importado com sucesso.
# Registro 121 importado com sucesso.
# Registro 122 importado com sucesso.
# Registro 123 importado com sucesso.
# Registro 124 importado com sucesso.
# Registro 125 importado com sucesso.
# Registro 126 importado com sucesso.
# Registro 127 importado com sucesso.
# Registro 128 importado com sucesso.
# Registro 129 importado com sucesso.
# Registro 130 importado com sucesso.
# Registro 131 importado com sucesso.
# Registro 132 importado com sucesso.
# Registro 133 importado com sucesso.
# Registro 134 importado com sucesso.
# Registro 135 importado com sucesso.
# Registro 136 importado com sucesso.
# Registro 137 importado com sucesso.
# Registro 138 importado com sucesso.
# Registro 139 importado com sucesso.
# Registro 140 importado com sucesso.
# Registro 141 importado com sucesso.
# Registro 142 importado com sucesso.
# Registro 143 importado com sucesso.
# Registro 144 importado com sucesso.
# Registro 145 importado com sucesso.
# Registro 146 importado com sucesso.
# Registro 147 importado com sucesso.
# Registro 148 importado com sucesso.
# Registro 149 importado com sucesso.
# Registro 150 importado com sucesso.
# Registro 151 importado com sucesso.
# Registro 152 importado com sucesso.
# Registro 153 importado com sucesso.
# Registro 154 importado com sucesso.
# Registro 155 importado com sucesso.
# Registro 156 importado com sucesso.
# Registro 157 importado com sucesso.
# Registro 158 importado com sucesso.
# Registro 159 importado com sucesso.
# Registro 160 importado com sucesso.
# Registro 161 importado com sucesso.
# Registro 162 importado com sucesso.
# Registro 163 importado com sucesso.
# Registro 164 importado com sucesso.
# Registro 165 importado com sucesso.
# Registro 166 importado com sucesso.
# Registro 167 importado com sucesso.
# Registro 168 importado com sucesso.
# Registro 169 importado com sucesso.
# Registro 170 importado com sucesso.
# Registro 171 importado com sucesso.
# Registro 172 importado com sucesso.
# Registro 173 importado com sucesso.
# Registro 174 importado com sucesso.
# Registro 175 importado com sucesso.
# Registro 176 importado com sucesso.
# Registro 177 importado com sucesso.
# Registro 178 importado com sucesso.
# Registro 179 importado com sucesso.
# Registro 180 importado com sucesso.
# Registro 181 importado com sucesso.
# Registro 182 importado com sucesso.
# Registro 183 importado com sucesso.
# Registro 184 importado com sucesso.
# Registro 185 importado com sucesso.
# Registro 186 importado com sucesso.
# Registro 187 importado com sucesso.
# Registro 188 importado com sucesso.
# Registro 189 importado com sucesso.
# Registro 190 importado com sucesso.
# Registro 191 importado com sucesso.
# Registro 192 importado com sucesso.
# Registro 193 importado com sucesso.
# Registro 194 importado com sucesso.
# Registro 195 importado com sucesso.
# Registro 196 importado com sucesso.
# Registro 197 importado com sucesso.
# Registro 198 importado com sucesso.
# Registro 199 importado com sucesso.
# Registro 200 importado com sucesso.
# Registro 201 importado com sucesso.
# Registro 202 importado com sucesso.
# Registro 203 importado com sucesso.
# Registro 204 importado com sucesso.
# Registro 205 importado com sucesso.
# Registro 206 importado com sucesso.
# Registro 207 importado com sucesso.
# Registro 208 importado com sucesso.
# Registro 209 importado com sucesso.
# Registro 210 importado com sucesso.
# Registro 211 importado com sucesso.
# Registro 212 importado com sucesso.
# Registro 213 importado com sucesso.
# Registro 214 importado com sucesso.
# Registro 215 importado com sucesso.
# Registro 216 importado com sucesso.
# Registro 217 importado com sucesso.
# Registro 218 importado com sucesso.
# Registro 219 importado com sucesso.
# Registro 220 importado com sucesso.
# Registro 221 importado com sucesso.
# Registro 222 importado com sucesso.
# Registro 223 importado com sucesso.
# Registro 224 importado com sucesso.
# Registro 225 importado com sucesso.
# Registro 226 importado com sucesso.
# Registro 227 importado com sucesso.
# Registro 228 importado com sucesso.
# Registro 229 importado com sucesso.
# Registro 230 importado com sucesso.
# Registro 231 importado com sucesso.
# Registro 232 importado com sucesso.
# Registro 233 importado com sucesso.
# Registro 234 importado com sucesso.
# Registro 235 importado com sucesso.
# Registro 236 importado com sucesso.
# Registro 237 importado com sucesso.
# Registro 238 importado com sucesso.
# Registro 239 importado com sucesso.
# Registro 240 importado com sucesso.
# Registro 241 importado com sucesso.
# Registro 242 importado com sucesso.
# Registro 243 importado com sucesso.
# Registro 244 importado com sucesso.
# Registro 245 importado com sucesso.
# Registro 246 importado com sucesso.
# Registro 247 importado com sucesso.
# Registro 248 importado com sucesso.
# Registro 249 importado com sucesso.
# Registro 250 importado com sucesso.
# Registro 251 importado com sucesso.
# Registro 252 importado com sucesso.
# Registro 253 importado com sucesso.
# Registro 254 importado com sucesso.
# Registro 255 importado com sucesso.
# Registro 256 importado com sucesso.
# Registro 257 importado com sucesso.
# Registro 258 importado com sucesso.
# Registro 259 importado com sucesso.
# Registro 260 importado com sucesso.
# Registro 261 importado com sucesso.
# Registro 262 importado com sucesso.
# Registro 263 importado com sucesso.
# Registro 264 importado com sucesso.
# Registro 265 importado com sucesso.
# Registro 266 importado com sucesso.
# Registro 267 importado com sucesso.
# Registro 268 importado com sucesso.
# Registro 269 importado com sucesso.
# Registro 270 importado com sucesso.
# Registro 271 importado com sucesso.
# Registro 272 importado com sucesso.
# Registro 273 importado com sucesso.
# Registro 274 importado com sucesso.
# Registro 275 importado com sucesso.
# Registro 276 importado com sucesso.
# Registro 277 importado com sucesso.
# Registro 278 importado com sucesso.
# Registro 279 importado com sucesso.
# Registro 280 importado com sucesso.
# Registro 281 importado com sucesso.
# Registro 282 importado com sucesso.
# Registro 283 importado com sucesso.
# Registro 284 importado com sucesso.
# Registro 285 importado com sucesso.
# Registro 286 importado com sucesso.
# Registro 287 importado com sucesso.
# Registro 288 importado com sucesso.
# Registro 289 importado com sucesso.
# Registro 290 importado com sucesso.
# Registro 291 importado com sucesso.
# Registro 292 importado com sucesso.
# Registro 293 importado com sucesso.
# Registro 294 importado com sucesso.
# Registro 295 importado com sucesso.
# Registro 296 importado com sucesso.
# Registro 297 importado com sucesso.
# Registro 298 importado com sucesso.
# Registro 299 importado com sucesso.
# Registro 300 importado com sucesso.
# Registro 301 importado com sucesso.
# Registro 302 importado com sucesso.
# Registro 303 importado com sucesso.
# Registro 304 importado com sucesso.
# Registro 305 importado com sucesso.
# Registro 306 importado com sucesso.
# Registro 307 importado com sucesso.
# Registro 308 importado com sucesso.
# Registro 309 importado com sucesso.
# Registro 310 importado com sucesso.
# Registro 311 importado com sucesso.
# Registro 312 importado com sucesso.
# Registro 313 importado com sucesso.
# Registro 314 importado com sucesso.
# Registro 315 importado com sucesso.
# Registro 316 importado com sucesso.
# Registro 317 importado com sucesso.
# Registro 318 importado com sucesso.
# Registro 319 importado com sucesso.
# Registro 320 importado com sucesso.
# Registro 321 importado com sucesso.
# Registro 322 importado com sucesso.
# Registro 323 importado com sucesso.
# Registro 324 importado com sucesso.
# Registro 325 importado com sucesso.
# Registro 326 importado com sucesso.
# Registro 327 importado com sucesso.
# Registro 328 importado com sucesso.
# Registro 329 importado com sucesso.
# Registro 330 importado com sucesso.
# Registro 331 importado com sucesso.
# Registro 332 importado com sucesso.
# Registro 333 importado com sucesso.
# Registro 334 importado com sucesso.
# Registro 335 importado com sucesso.
# Registro 336 importado com sucesso.
# Registro 337 importado com sucesso.
# Registro 338 importado com sucesso.
# Registro 339 importado com sucesso.
# Registro 340 importado com sucesso.
# Registro 341 importado com sucesso.
# Registro 342 importado com sucesso.
# Registro 343 importado com sucesso.
# Registro 344 importado com sucesso.
# Registro 345 importado com sucesso.
# Registro 346 importado com sucesso.
# Registro 347 importado com sucesso.
# Registro 348 importado com sucesso.
# Registro 349 importado com sucesso.
# Registro 350 importado com sucesso.
# Registro 351 importado com sucesso.
# Registro 352 importado com sucesso.
# Registro 353 importado com sucesso.
# Registro 354 importado com sucesso.
# Registro 355 importado com sucesso.
# Registro 356 importado com sucesso.
# Registro 357 importado com sucesso.
# Registro 358 importado com sucesso.
# Registro 359 importado com sucesso.
# Registro 360 importado com sucesso.
# Registro 361 importado com sucesso.
# Registro 362 importado com sucesso.
# Registro 363 importado com sucesso.
# Registro 364 importado com sucesso.
# Registro 365 importado com sucesso.
# Registro 366 importado com sucesso.
# Registro 367 importado com sucesso.
# Registro 368 importado com sucesso.
# Registro 369 importado com sucesso.
# Registro 370 importado com sucesso.
# Registro 371 importado com sucesso.
# Registro 372 importado com sucesso.
# Registro 373 importado com sucesso.
# Registro 374 importado com sucesso.
# Registro 375 importado com sucesso.
# Registro 376 importado com sucesso.
# Registro 377 importado com sucesso.
# Registro 378 importado com sucesso.
# Registro 379 importado com sucesso.
# Registro 380 importado com sucesso.
# Registro 381 importado com sucesso.
# Registro 382 importado com sucesso.
# Registro 383 importado com sucesso.
# Registro 384 importado com sucesso.
# Registro 385 importado com sucesso.
# Registro 386 importado com sucesso.
# Registro 387 importado com sucesso.
# Registro 388 importado com sucesso.
# Registro 389 importado com sucesso.
# Registro 390 importado com sucesso.
# Registro 391 importado com sucesso.
# Registro 392 importado com sucesso.
# Registro 393 importado com sucesso.
# Registro 394 importado com sucesso.
# Registro 395 importado com sucesso.
# Registro 396 importado com sucesso.
# Registro 397 importado com sucesso.
# Registro 398 importado com sucesso.
# Registro 399 importado com sucesso.
# Registro 400 importado com sucesso.
# Registro 401 importado com sucesso.
# Registro 402 importado com sucesso.
# Registro 403 importado com sucesso.
# Registro 404 importado com sucesso.
# Registro 405 importado com sucesso.
# Registro 406 importado com sucesso.
# Registro 407 importado com sucesso.
# Registro 408 importado com sucesso.
# Registro 409 importado com sucesso.
# Registro 410 importado com sucesso.
# Registro 411 importado com sucesso.
# Registro 412 importado com sucesso.
# Registro 413 importado com sucesso.
# Registro 414 importado com sucesso.
# Registro 415 importado com sucesso.
# Registro 416 importado com sucesso.
# Registro 417 importado com sucesso.
# Registro 418 importado com sucesso.
# Registro 419 importado com sucesso.
# Registro 420 importado com sucesso.
# Registro 421 importado com sucesso.
# Registro 422 importado com sucesso.
# Registro 423 importado com sucesso.
# Registro 424 importado com sucesso.
# Registro 425 importado com sucesso.
# Registro 426 importado com sucesso.
# Registro 427 importado com sucesso.
# Registro 428 importado com sucesso.
# Registro 429 importado com sucesso.
# Registro 430 importado com sucesso.
# Registro 431 importado com sucesso.
# Registro 432 importado com sucesso.
# Registro 433 importado com sucesso.
# Registro 434 importado com sucesso.
# Registro 435 importado com sucesso.
# Registro 436 importado com sucesso.
# Registro 437 importado com sucesso.
# Registro 438 importado com sucesso.
# Registro 439 importado com sucesso.
# Registro 440 importado com sucesso.
# Registro 441 importado com sucesso.
# Registro 442 importado com sucesso.
# Registro 443 importado com sucesso.
# Registro 444 importado com sucesso.
# Registro 445 importado com sucesso.
# Registro 446 importado com sucesso.
# Registro 447 importado com sucesso.
# Registro 448 importado com sucesso.
# Registro 449 importado com sucesso.
# Registro 450 importado com sucesso.
# Registro 451 importado com sucesso.
# Registro 452 importado com sucesso.
# Registro 453 importado com sucesso.
# Registro 454 importado com sucesso.
# Registro 455 importado com sucesso.
# Registro 456 importado com sucesso.
# Registro 457 importado com sucesso.
# Registro 458 importado com sucesso.
# Registro 459 importado com sucesso.
# Registro 460 importado com sucesso.
# Registro 461 importado com sucesso.
# Registro 462 importado com sucesso.
# Registro 463 importado com sucesso.
# Registro 464 importado com sucesso.
# Registro 465 importado com sucesso.
# Registro 466 importado com sucesso.
# Registro 467 importado com sucesso.
# Registro 468 importado com sucesso.
# Registro 469 importado com sucesso.
# Registro 470 importado com sucesso.
# Registro 471 importado com sucesso.
# Registro 472 importado com sucesso.
# Registro 473 importado com sucesso.
# Registro 474 importado com sucesso.
# Registro 475 importado com sucesso.
# Registro 476 importado com sucesso.
# Registro 477 importado com sucesso.
# Registro 478 importado com sucesso.
# Registro 479 importado com sucesso.
# Registro 480 importado com sucesso.
# Registro 481 importado com sucesso.
# Registro 482 importado com sucesso.
# Registro 483 importado com sucesso.
# Registro 484 importado com sucesso.
# Registro 485 importado com sucesso.
# Registro 486 importado com sucesso.
# Registro 487 importado com sucesso.
# Registro 488 importado com sucesso.
# Registro 489 importado com sucesso.
# Registro 490 importado com sucesso.
# Registro 491 importado com sucesso.
# Registro 492 importado com sucesso.
# Registro 493 importado com sucesso.
# Registro 494 importado com sucesso.
# Registro 495 importado com sucesso.
# Registro 496 importado com sucesso.
# Registro 497 importado com sucesso.
# Registro 498 importado com sucesso.
# Registro 499 importado com sucesso.
# Registro 500 importado com sucesso.
# Registro 501 importado com sucesso.
# Registro 502 importado com sucesso.
# Registro 503 importado com sucesso.
# Registro 504 importado com sucesso.
# Registro 505 importado com sucesso.
# Registro 506 importado com sucesso.
# Registro 507 importado com sucesso.
# Registro 508 importado com sucesso.
# Registro 509 importado com sucesso.
# Registro 510 importado com sucesso.
# Registro 511 importado com sucesso.
# Registro 512 importado com sucesso.
# Registro 513 importado com sucesso.
# Registro 514 importado com sucesso.
# Registro 515 importado com sucesso.
# Registro 516 importado com sucesso.
# Registro 517 importado com sucesso.
# Registro 518 importado com sucesso.
# Registro 519 importado com sucesso.
# Registro 520 importado com sucesso.
# Registro 521 importado com sucesso.
# Registro 522 importado com sucesso.
# Registro 523 importado com sucesso.
# Registro 524 importado com sucesso.
# Registro 525 importado com sucesso.
# Registro 526 importado com sucesso.
# Registro 527 importado com sucesso.
# Registro 528 importado com sucesso.
# Registro 529 importado com sucesso.
# Registro 530 importado com sucesso.
# Registro 531 importado com sucesso.
# Registro 532 importado com sucesso.
# Registro 533 importado com sucesso.
# Registro 534 importado com sucesso.
# Registro 535 importado com sucesso.
# Registro 536 importado com sucesso.
# Registro 537 importado com sucesso.
# Registro 538 importado com sucesso.
# Registro 539 importado com sucesso.
# Registro 540 importado com sucesso.
# Registro 541 importado com sucesso.
# Registro 542 importado com sucesso.
# Registro 543 importado com sucesso.
# Registro 544 importado com sucesso.
# Registro 545 importado com sucesso.
# Registro 546 importado com sucesso.
# Registro 547 importado com sucesso.
# Registro 548 importado com sucesso.
# Registro 549 importado com sucesso.
# Registro 550 importado com sucesso.
# Registro 551 importado com sucesso.
# Registro 552 importado com sucesso.
# Registro 553 importado com sucesso.
# Registro 554 importado com sucesso.
# Registro 555 importado com sucesso.
# Registro 556 importado com sucesso.
# Registro 557 importado com sucesso.
# Registro 558 importado com sucesso.
# Registro 559 importado com sucesso.
# Registro 560 importado com sucesso.
# Registro 561 importado com sucesso.
# Registro 562 importado com sucesso.
# Registro 563 importado com sucesso.
# Registro 564 importado com sucesso.
# Registro 565 importado com sucesso.
# Registro 566 importado com sucesso.
# Registro 567 importado com sucesso.
# Registro 568 importado com sucesso.
# Registro 569 importado com sucesso.
# Registro 570 importado com sucesso.
# Registro 571 importado com sucesso.
# Registro 572 importado com sucesso.
# Registro 573 importado com sucesso.
# Registro 574 importado com sucesso.
# Registro 575 importado com sucesso.
# Registro 576 importado com sucesso.
# Registro 577 importado com sucesso.
# Registro 578 importado com sucesso.
# Registro 579 importado com sucesso.
# Registro 580 importado com sucesso.
# Registro 581 importado com sucesso.
# Registro 582 importado com sucesso.
# Registro 583 importado com sucesso.
# Registro 584 importado com sucesso.
# Registro 585 importado com sucesso.
# Registro 586 importado com sucesso.
# Registro 587 importado com sucesso.
# Registro 588 importado com sucesso.
# Registro 589 importado com sucesso.
# Registro 590 importado com sucesso.
# Registro 591 importado com sucesso.
# Registro 592 importado com sucesso.
# Registro 593 importado com sucesso.
# Registro 594 importado com sucesso.
# Registro 595 importado com sucesso.
# Registro 596 importado com sucesso.
# Registro 597 importado com sucesso.
# Registro 598 importado com sucesso.
# Registro 599 importado com sucesso.
# Registro 600 importado com sucesso.
# Registro 601 importado com sucesso.
# Registro 602 importado com sucesso.
# Registro 603 importado com sucesso.
# Registro 604 importado com sucesso.
# Registro 605 importado com sucesso.
# Registro 606 importado com sucesso.
# Registro 607 importado com sucesso.
# Registro 608 importado com sucesso.
# Registro 609 importado com sucesso.
# Registro 610 importado com sucesso.
# Registro 611 importado com sucesso.
# Registro 612 importado com sucesso.
# Registro 613 importado com sucesso.
# Registro 614 importado com sucesso.
# Registro 615 importado com sucesso.
# Registro 616 importado com sucesso.
# Registro 617 importado com sucesso.
# Registro 618 importado com sucesso.
# Registro 619 importado com sucesso.
# Registro 620 importado com sucesso.
# Registro 621 importado com sucesso.
# Registro 622 importado com sucesso.
# Registro 623 importado com sucesso.
# Registro 624 importado com sucesso.
# Registro 625 importado com sucesso.
# Registro 626 importado com sucesso.
# Registro 627 importado com sucesso.
# Registro 628 importado com sucesso.
# Registro 629 importado com sucesso.
# Registro 630 importado com sucesso.
# Registro 631 importado com sucesso.
# Registro 632 importado com sucesso.
# Registro 633 importado com sucesso.
# Registro 634 importado com sucesso.
# Registro 635 importado com sucesso.
# Registro 636 importado com sucesso.
# Registro 637 importado com sucesso.
# Registro 638 importado com sucesso.
# Registro 639 importado com sucesso.
# Registro 640 importado com sucesso.
# Registro 641 importado com sucesso.
# Registro 642 importado com sucesso.
# Registro 643 importado com sucesso.
# Registro 644 importado com sucesso.
# Registro 645 importado com sucesso.
# Registro 646 importado com sucesso.
# Registro 647 importado com sucesso.
# Registro 648 importado com sucesso.
# Registro 649 importado com sucesso.
# Registro 650 importado com sucesso.
# Registro 651 importado com sucesso.
# Registro 652 importado com sucesso.
# Registro 653 importado com sucesso.
# Registro 654 importado com sucesso.
# Registro 655 importado com sucesso.
# Registro 656 importado com sucesso.
# Registro 657 importado com sucesso.
# Registro 658 importado com sucesso.
# Registro 659 importado com sucesso.
# Registro 660 importado com sucesso.
# Registro 661 importado com sucesso.
# Registro 662 importado com sucesso.
# Registro 663 importado com sucesso.
# Registro 664 importado com sucesso.
# Registro 665 importado com sucesso.
# Registro 666 importado com sucesso.
# Registro 667 importado com sucesso.
# Registro 668 importado com sucesso.
# Registro 669 importado com sucesso.
# Registro 670 importado com sucesso.
# Registro 671 importado com sucesso.
# Registro 672 importado com sucesso.
# Registro 673 importado com sucesso.
# Registro 674 importado com sucesso.
# Registro 675 importado com sucesso.
# Registro 676 importado com sucesso.
# Registro 677 importado com sucesso.
# Registro 678 importado com sucesso.
# Registro 679 importado com sucesso.
# Registro 680 importado com sucesso.
# Registro 681 importado com sucesso.
# Registro 682 importado com sucesso.
# Registro 683 importado com sucesso.
# Registro 684 importado com sucesso.
# Registro 685 importado com sucesso.
# Registro 686 importado com sucesso.
# Registro 687 importado com sucesso.
# Registro 688 importado com sucesso.
# Registro 689 importado com sucesso.
# Registro 690 importado com sucesso.
# Registro 691 importado com sucesso.
# Registro 692 importado com sucesso.
# Registro 693 importado com sucesso.
# Registro 694 importado com sucesso.
# Registro 695 importado com sucesso.
# Registro 696 importado com sucesso.
# Registro 697 importado com sucesso.
# Registro 698 importado com sucesso.
# Registro 699 importado com sucesso.
# Registro 700 importado com sucesso.
# Registro 701 importado com sucesso.
# Registro 702 importado com sucesso.
# Registro 703 importado com sucesso.
# Registro 704 importado com sucesso.
# Registro 705 importado com sucesso.
# Registro 706 importado com sucesso.
# Registro 707 importado com sucesso.
# Registro 708 importado com sucesso.
# Registro 709 importado com sucesso.
# Registro 710 importado com sucesso.
# Registro 711 importado com sucesso.
# Registro 712 importado com sucesso.
# Registro 713 importado com sucesso.
# Registro 714 importado com sucesso.
# Registro 715 importado com sucesso.
# Registro 716 importado com sucesso.
# Registro 717 importado com sucesso.
# Registro 718 importado com sucesso.
# Registro 719 importado com sucesso.
# Registro 720 importado com sucesso.
# Registro 721 importado com sucesso.
# Registro 722 importado com sucesso.
# Registro 723 importado com sucesso.
# Registro 724 importado com sucesso.
# Registro 725 importado com sucesso.
# Registro 726 importado com sucesso.
# Registro 727 importado com sucesso.
# Registro 728 importado com sucesso.
# Registro 729 importado com sucesso.
# Registro 730 importado com sucesso.
# Registro 731 importado com sucesso.
# Registro 732 importado com sucesso.
# Registro 733 importado com sucesso.
# Registro 734 importado com sucesso.
# Registro 735 importado com sucesso.
# Registro 736 importado com sucesso.
# Registro 737 importado com sucesso.
# Registro 738 importado com sucesso.
# Registro 739 importado com sucesso.
# Registro 740 importado com sucesso.
# Registro 741 importado com sucesso.
# Registro 742 importado com sucesso.
# Registro 743 importado com sucesso.
# Registro 744 importado com sucesso.
# Registro 745 importado com sucesso.
# Registro 746 importado com sucesso.
# Registro 747 importado com sucesso.
# Registro 748 importado com sucesso.
# Registro 749 importado com sucesso.
# Registro 750 importado com sucesso.
# Registro 751 importado com sucesso.
# Registro 752 importado com sucesso.
# Registro 753 importado com sucesso.
# Registro 754 importado com sucesso.
# Registro 755 importado com sucesso.
# Registro 756 importado com sucesso.
# Registro 757 importado com sucesso.
# Registro 758 importado com sucesso.
# Registro 759 importado com sucesso.
# Registro 760 importado com sucesso.
# Registro 761 importado com sucesso.
# Registro 762 importado com sucesso.
# Registro 763 importado com sucesso.
# Registro 764 importado com sucesso.
# Registro 765 importado com sucesso.
# Registro 766 importado com sucesso.
# Registro 767 importado com sucesso.
# Registro 768 importado com sucesso.
# Registro 769 importado com sucesso.
# Registro 770 importado com sucesso.
# Registro 771 importado com sucesso.
# Registro 772 importado com sucesso.
# Registro 773 importado com sucesso.
# Registro 774 importado com sucesso.
# Registro 775 importado com sucesso.
# Registro 776 importado com sucesso.
# Registro 777 importado com sucesso.
# Registro 778 importado com sucesso.
# Registro 779 importado com sucesso.
# Registro 780 importado com sucesso.
# Registro 781 importado com sucesso.
# Registro 782 importado com sucesso.
# Registro 783 importado com sucesso.
# Registro 784 importado com sucesso.
# Registro 785 importado com sucesso.
# Registro 786 importado com sucesso.
# Registro 787 importado com sucesso.
# Registro 788 importado com sucesso.
# Registro 789 importado com sucesso.
# Registro 790 importado com sucesso.
# Registro 791 importado com sucesso.
# Registro 792 importado com sucesso.
# Registro 793 importado com sucesso.
# Registro 794 importado com sucesso.
# Registro 795 importado com sucesso.
# Registro 796 importado com sucesso.
# Registro 797 importado com sucesso.
# Registro 798 importado com sucesso.
# Registro 799 importado com sucesso.
# Registro 800 importado com sucesso.
# Registro 801 importado com sucesso.
# Registro 802 importado com sucesso.
# Registro 803 importado com sucesso.
# Registro 804 importado com sucesso.
# Registro 805 importado com sucesso.
# Registro 806 importado com sucesso.
# Registro 807 importado com sucesso.
# Registro 808 importado com sucesso.
# Registro 809 importado com sucesso.
# Registro 810 importado com sucesso.
# Registro 811 importado com sucesso.
# Registro 812 importado com sucesso.
# Registro 813 importado com sucesso.
# Registro 814 importado com sucesso.
# Registro 815 importado com sucesso.
# Registro 816 importado com sucesso.
# Registro 817 importado com sucesso.
# Registro 818 importado com sucesso.
# Registro 819 importado com sucesso.
# Registro 820 importado com sucesso.
# Registro 821 importado com sucesso.
# Registro 822 importado com sucesso.
# Registro 823 importado com sucesso.
# Registro 824 importado com sucesso.
# Registro 825 importado com sucesso.
# Registro 826 importado com sucesso.
# Registro 827 importado com sucesso.
# Registro 828 importado com sucesso.
# Registro 829 importado com sucesso.
# Registro 830 importado com sucesso.
# Registro 831 importado com sucesso.
# Registro 832 importado com sucesso.
# Registro 833 importado com sucesso.
# Registro 834 importado com sucesso.
# Registro 835 importado com sucesso.
# Registro 836 importado com sucesso.
# Registro 837 importado com sucesso.
# Registro 838 importado com sucesso.
# Registro 839 importado com sucesso.
# Registro 840 importado com sucesso.
# Registro 841 importado com sucesso.
# Registro 842 importado com sucesso.
# Registro 843 importado com sucesso.
# Registro 844 importado com sucesso.
# Registro 845 importado com sucesso.
# Registro 846 importado com sucesso.
# Registro 847 importado com sucesso.
# Registro 848 importado com sucesso.
# Registro 849 importado com sucesso.
# Registro 850 importado com sucesso.
# Registro 851 importado com sucesso.
# Registro 852 importado com sucesso.
# Registro 853 importado com sucesso.
# Registro 854 importado com sucesso.
# Registro 855 importado com sucesso.
# Registro 856 importado com sucesso.
# Registro 857 importado com sucesso.
# Registro 858 importado com sucesso.
# Registro 859 importado com sucesso.
# Registro 860 importado com sucesso.
# Registro 861 importado com sucesso.
# Registro 862 importado com sucesso.
# Registro 863 importado com sucesso.
# Registro 864 importado com sucesso.
# Registro 865 importado com sucesso.
# Registro 866 importado com sucesso.
# Registro 867 importado com sucesso.
# Registro 868 importado com sucesso.
# Registro 869 importado com sucesso.
# Registro 870 importado com sucesso.
# Registro 871 importado com sucesso.
# Registro 872 importado com sucesso.
# Registro 873 importado com sucesso.
# Registro 874 importado com sucesso.
# Registro 875 importado com sucesso.
# Registro 876 importado com sucesso.
# Registro 877 importado com sucesso.
# Registro 878 importado com sucesso.
# Registro 879 importado com sucesso.
# Registro 880 importado com sucesso.
# Registro 881 importado com sucesso.
# Registro 882 importado com sucesso.
# Registro 883 importado com sucesso.
# Registro 884 importado com sucesso.
# Registro 885 importado com sucesso.
# Registro 886 importado com sucesso.
# Registro 887 importado com sucesso.
# Registro 888 importado com sucesso.
# Registro 889 importado com sucesso.
# Registro 890 importado com sucesso.
# Registro 891 importado com sucesso.
# Registro 892 importado com sucesso.
# Registro 893 importado com sucesso.
# Registro 894 importado com sucesso.
# Registro 895 importado com sucesso.
# Registro 896 importado com sucesso.
# Registro 897 importado com sucesso.
# Registro 898 importado com sucesso.
# Registro 899 importado com sucesso.
# Registro 900 importado com sucesso.
# Registro 901 importado com sucesso.
# Registro 902 importado com sucesso.
# Registro 903 importado com sucesso.
# Registro 904 importado com sucesso.
# Registro 905 importado com sucesso.
# Registro 906 importado com sucesso.
# Registro 907 importado com sucesso.
# Registro 908 importado com sucesso.
# Registro 909 importado com sucesso.
# Registro 910 importado com sucesso.
# Registro 911 importado com sucesso.
# Registro 912 importado com sucesso.
# Registro 913 importado com sucesso.
# Registro 914 importado com sucesso.
# Registro 915 importado com sucesso.
# Registro 916 importado com sucesso.
# Registro 917 importado com sucesso.
# Registro 918 importado com sucesso.
# Registro 919 importado com sucesso.
# Registro 920 importado com sucesso.
# Registro 921 importado com sucesso.
# Registro 922 importado com sucesso.
# Registro 923 importado com sucesso.
# Registro 924 importado com sucesso.
# Registro 925 importado com sucesso.
# Registro 926 importado com sucesso.
# Registro 927 importado com sucesso.
# Registro 928 importado com sucesso.
# Registro 929 importado com sucesso.
# Registro 930 importado com sucesso.
# Registro 931 importado com sucesso.
# Registro 932 importado com sucesso.
# Registro 933 importado com sucesso.
# Registro 934 importado com sucesso.
# Registro 935 importado com sucesso.
# Registro 936 importado com sucesso.
# Registro 937 importado com sucesso.
# Registro 938 importado com sucesso.
# Registro 939 importado com sucesso.
# Registro 940 importado com sucesso.
# Registro 941 importado com sucesso.
# Registro 942 importado com sucesso.
# Registro 943 importado com sucesso.
# Registro 944 importado com sucesso.
# Registro 945 importado com sucesso.
# Registro 946 importado com sucesso.
# Registro 947 importado com sucesso.
# Registro 948 importado com sucesso.
# Registro 949 importado com sucesso.
# Registro 950 importado com sucesso.
# Registro 951 importado com sucesso.
# Registro 952 importado com sucesso.
# Registro 953 importado com sucesso.
# Registro 954 importado com sucesso.
# Registro 955 importado com sucesso.
# Registro 956 importado com sucesso.
# Registro 957 importado com sucesso.
# Registro 958 importado com sucesso.
# Registro 959 importado com sucesso.
# Registro 960 importado com sucesso.
# Registro 961 importado com sucesso.
# Registro 962 importado com sucesso.
# Registro 963 importado com sucesso.
# Registro 964 importado com sucesso.
# Registro 965 importado com sucesso.
# Registro 966 importado com sucesso.
# Registro 967 importado com sucesso.
# Registro 968 importado com sucesso.
# Registro 969 importado com sucesso.
# Registro 970 importado com sucesso.
# Registro 971 importado com sucesso.
# Registro 972 importado com sucesso.
# Registro 973 importado com sucesso.
# Registro 974 importado com sucesso.
# Registro 975 importado com sucesso.
# Registro 976 importado com sucesso.
# Registro 977 importado com sucesso.
# Registro 978 importado com sucesso.
# Registro 979 importado com sucesso.
# Registro 980 importado com sucesso.
# Registro 981 importado com sucesso.
# Registro 982 importado com sucesso.
# Registro 983 importado com sucesso.
# Registro 984 importado com sucesso.
# Registro 985 importado com sucesso.
# Registro 986 importado com sucesso.
# Registro 987 importado com sucesso.
# Registro 988 importado com sucesso.
# Registro 989 importado com sucesso.
# Registro 990 importado com sucesso.
# Registro 991 importado com sucesso.
# Registro 992 importado com sucesso.
# Registro 993 importado com sucesso.
# Registro 994 importado com sucesso.
# Registro 995 importado com sucesso.
# Registro 996 importado com sucesso.
# Registro 997 importado com sucesso.
# Registro 998 importado com sucesso.
# Registro 999 importado com sucesso.
# Registro 1000 importado com sucesso.
# Registro 1001 importado com sucesso.
# Registro 1002 importado com sucesso.
# Registro 1003 importado com sucesso.
# Registro 1004 importado com sucesso.
# Registro 1005 importado com sucesso.
# Registro 1006 importado com sucesso.
# Registro 1007 importado com sucesso.
# Registro 1008 importado com sucesso.
# Registro 1009 importado com sucesso.
# Registro 1010 importado com sucesso.
# Registro 1011 importado com sucesso.
# Registro 1012 importado com sucesso.
# Registro 1013 importado com sucesso.
# Registro 1014 importado com sucesso.
# Registro 1015 importado com sucesso.
# Registro 1016 importado com sucesso.
# Registro 1017 importado com sucesso.
# Registro 1018 importado com sucesso.
# Registro 1019 importado com sucesso.
# Registro 1020 importado com sucesso.
# Registro 1021 importado com sucesso.
# Registro 1022 importado com sucesso.
# Registro 1023 importado com sucesso.
# Registro 1024 importado com sucesso.
# Registro 1025 importado com sucesso.
# Registro 1026 importado com sucesso.
# Registro 1027 importado com sucesso.
# Registro 1028 importado com sucesso.
# Registro 1029 importado com sucesso.
# Registro 1030 importado com sucesso.
# Registro 1031 importado com sucesso.
# Registro 1032 importado com sucesso.
# Registro 1033 importado com sucesso.
# Registro 1034 importado com sucesso.
# Registro 1035 importado com sucesso.
# Registro 1036 importado com sucesso.
# Registro 1037 importado com sucesso.
# Registro 1038 importado com sucesso.
# Registro 1039 importado com sucesso.
# Registro 1040 importado com sucesso.
# Registro 1041 importado com sucesso.
# Registro 1042 importado com sucesso.
# Registro 1043 importado com sucesso.
# Registro 1044 importado com sucesso.
# Registro 1045 importado com sucesso.
# Registro 1046 importado com sucesso.
# Registro 1047 importado com sucesso.
# Registro 1048 importado com sucesso.
# Registro 1049 importado com sucesso.
# Registro 1050 importado com sucesso.
# Registro 1051 importado com sucesso.
# Registro 1052 importado com sucesso.
# Registro 1053 importado com sucesso.
# Registro 1054 importado com sucesso.
# Registro 1055 importado com sucesso.
# Registro 1056 importado com sucesso.
# Registro 1057 importado com sucesso.
# Registro 1058 importado com sucesso.
# Registro 1059 importado com sucesso.
# Registro 1060 importado com sucesso.
# Registro 1061 importado com sucesso.
# Registro 1062 importado com sucesso.
# Registro 1063 importado com sucesso.
# Registro 1064 importado com sucesso.
# Registro 1065 importado com sucesso.
# Registro 1066 importado com sucesso.
# Registro 1067 importado com sucesso.
# Registro 1068 importado com sucesso.
# Registro 1069 importado com sucesso.
# Registro 1070 importado com sucesso.
# Registro 1071 importado com sucesso.
# Registro 1072 importado com sucesso.
# Registro 1073 importado com sucesso.
# Registro 1074 importado com sucesso.
# Registro 1075 importado com sucesso.
# Registro 1076 importado com sucesso.
# Registro 1077 importado com sucesso.
# Registro 1078 importado com sucesso.
# Registro 1079 importado com sucesso.
# Registro 1080 importado com sucesso.
# Registro 1081 importado com sucesso.
# Registro 1082 importado com sucesso.
# Registro 1083 importado com sucesso.
# Registro 1084 importado com sucesso.
# Registro 1085 importado com sucesso.
# Registro 1086 importado com sucesso.
# Registro 1087 importado com sucesso.
# Registro 1088 importado com sucesso.
# Registro 1089 importado com sucesso.
# Registro 1090 importado com sucesso.
# Registro 1091 importado com sucesso.
# Registro 1092 importado com sucesso.
# Registro 1093 importado com sucesso.
# Registro 1094 importado com sucesso.
# Registro 1095 importado com sucesso.
# Registro 1096 importado com sucesso.
# Registro 1097 importado com sucesso.
# Registro 1098 importado com sucesso.
# Registro 1099 importado com sucesso.
# Registro 1100 importado com sucesso.
# Registro 1101 importado com sucesso.
# Registro 1102 importado com sucesso.
# Registro 1103 importado com sucesso.
# Registro 1104 importado com sucesso.
# Registro 1105 importado com sucesso.
# Registro 1106 importado com sucesso.
# Registro 1107 importado com sucesso.
# Registro 1108 importado com sucesso.
# Registro 1109 importado com sucesso.
# Registro 1110 importado com sucesso.
# Registro 1111 importado com sucesso.
# Registro 1112 importado com sucesso.
# Registro 1113 importado com sucesso.
# Registro 1114 importado com sucesso.
# Registro 1115 importado com sucesso.
# Registro 1116 importado com sucesso.
# Registro 1117 importado com sucesso.
# Registro 1118 importado com sucesso.
# Registro 1119 importado com sucesso.
# Registro 1120 importado com sucesso.
# Registro 1121 importado com sucesso.
# Registro 1122 importado com sucesso.
# Registro 1123 importado com sucesso.
# Registro 1124 importado com sucesso.
# Registro 1125 importado com sucesso.
# Registro 1126 importado com sucesso.
# Registro 1127 importado com sucesso.
# Registro 1128 importado com sucesso.
# Registro 1129 importado com sucesso.
# Registro 1130 importado com sucesso.
# Registro 1131 importado com sucesso.
# Registro 1132 importado com sucesso.
# Registro 1133 importado com sucesso.
# Registro 1134 importado com sucesso.
# Registro 1135 importado com sucesso.
# Registro 1136 importado com sucesso.
# Registro 1137 importado com sucesso.
# Registro 1138 importado com sucesso.
# Registro 1139 importado com sucesso.
# Registro 1140 importado com sucesso.
# Registro 1141 importado com sucesso.
# Registro 1142 importado com sucesso.
# Registro 1143 importado com sucesso.
# Registro 1144 importado com sucesso.
# Registro 1145 importado com sucesso.
# Registro 1146 importado com sucesso.
# Registro 1147 importado com sucesso.
# Registro 1148 importado com sucesso.
# Registro 1149 importado com sucesso.
# Registro 1150 importado com sucesso.
# Registro 1151 importado com sucesso.
# Registro 1152 importado com sucesso.
# Registro 1153 importado com sucesso.
# Registro 1154 importado com sucesso.
# Registro 1155 importado com sucesso.
# Registro 1156 importado com sucesso.
# Registro 1157 importado com sucesso.
# Registro 1158 importado com sucesso.
# Registro 1159 importado com sucesso.
# Registro 1160 importado com sucesso.
# Registro 1161 importado com sucesso.
# Registro 1162 importado com sucesso.
# Registro 1163 importado com sucesso.
# Registro 1164 importado com sucesso.
# Registro 1165 importado com sucesso.
# Registro 1166 importado com sucesso.
# Registro 1167 importado com sucesso.
# Registro 1168 importado com sucesso.
# Registro 1169 importado com sucesso.
# Registro 1170 importado com sucesso.
# Registro 1171 importado com sucesso.
# Registro 1172 importado com sucesso.
# Registro 1173 importado com sucesso.
# Registro 1174 importado com sucesso.
# Registro 1175 importado com sucesso.
# Registro 1176 importado com sucesso.
# Registro 1177 importado com sucesso.
# Registro 1178 importado com sucesso.
# Registro 1179 importado com sucesso.
# Registro 1180 importado com sucesso.
# Registro 1181 importado com sucesso.
# Registro 1182 importado com sucesso.
# Registro 1183 importado com sucesso.
# Registro 1184 importado com sucesso.
# Registro 1185 importado com sucesso.
# Registro 1186 importado com sucesso.
# Registro 1187 importado com sucesso.
# Registro 1188 importado com sucesso.
# Registro 1189 importado com sucesso.
# Registro 1190 importado com sucesso.
# Registro 1191 importado com sucesso.
# Registro 1192 importado com sucesso.
# Registro 1193 importado com sucesso.
# Registro 1194 importado com sucesso.
# Registro 1195 importado com sucesso.
# Registro 1196 importado com sucesso.
# Registro 1197 importado com sucesso.
# Registro 1198 importado com sucesso.
# Registro 1199 importado com sucesso.
# Registro 1200 importado com sucesso.
# Registro 1201 importado com sucesso.
# Registro 1202 importado com sucesso.
# Registro 1203 importado com sucesso.
# Registro 1204 importado com sucesso.
# Registro 1205 importado com sucesso.
# Registro 1206 importado com sucesso.
# Registro 1207 importado com sucesso.
# Registro 1208 importado com sucesso.
# Registro 1209 importado com sucesso.
# Registro 1210 importado com sucesso.
# Registro 1211 importado com sucesso.
# Registro 1212 importado com sucesso.
# Registro 1213 importado com sucesso.
# Registro 1214 importado com sucesso.
# Registro 1215 importado com sucesso.
# Registro 1216 importado com sucesso.
# Registro 1217 importado com sucesso.
# Registro 1218 importado com sucesso.
# Registro 1219 importado com sucesso.
# Registro 1220 importado com sucesso.
# Registro 1221 importado com sucesso.
# Registro 1222 importado com sucesso.
# Registro 1223 importado com sucesso.
# Registro 1224 importado com sucesso.
# Registro 1225 importado com sucesso.
# Registro 1226 importado com sucesso.
# Registro 1227 importado com sucesso.
# Registro 1228 importado com sucesso.
# Registro 1229 importado com sucesso.
# Registro 1230 importado com sucesso.
# Registro 1231 importado com sucesso.
# Registro 1232 importado com sucesso.
# Registro 1233 importado com sucesso.
# Registro 1234 importado com sucesso.
# Registro 1235 importado com sucesso.
# Registro 1236 importado com sucesso.
# Registro 1237 importado com sucesso.
# Registro 1238 importado com sucesso.
# Registro 1239 importado com sucesso.
# Registro 1240 importado com sucesso.
# Registro 1241 importado com sucesso.
# Registro 1242 importado com sucesso.
# Registro 1243 importado com sucesso.
# Registro 1244 importado com sucesso.
# Registro 1245 importado com sucesso.
# Registro 1246 importado com sucesso.
# Registro 1247 importado com sucesso.
# Registro 1248 importado com sucesso.
# Registro 1249 importado com sucesso.
# Registro 1250 importado com sucesso.
# Registro 1251 importado com sucesso.
# Registro 1252 importado com sucesso.
# Registro 1253 importado com sucesso.
# Registro 1254 importado com sucesso.
# Registro 1255 importado com sucesso.
# Registro 1256 importado com sucesso.
# Registro 1257 importado com sucesso.
# Registro 1258 importado com sucesso.
# Registro 1259 importado com sucesso.
# Registro 1260 importado com sucesso.
# Registro 1261 importado com sucesso.
# Registro 1262 importado com sucesso.
# Registro 1263 importado com sucesso.
# Registro 1264 importado com sucesso.
# Registro 1265 importado com sucesso.
# Registro 1266 importado com sucesso.
# Registro 1267 importado com sucesso.
# Registro 1268 importado com sucesso.
